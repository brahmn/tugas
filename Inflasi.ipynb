.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 16 columns):
# bulan        12 non-null object
# 2006         13 non-null float64
# 2007         13 non-null float64
# 2008         13 non-null float64
# 2009         13 non-null float64
# 2010         13 non-null float64
# 2011         13 non-null float64
# 2012         13 non-null float64
# 2013         13 non-null float64
# 2014         13 non-null float64
# 2015         13 non-null float64
# 2016         13 non-null float64
# 2017         13 non-null float64
# 2018         13 non-null float64
# 2019         9 non-null float64
# rata-rata    12 non-null float64
# dtypes: float64(15), object(1)
# memory usage: 1.7+ KB

# %%
inflasi.max()
# Out:
# 2006         17.92
# 2007          6.95
# 2008         12.14
# 2009          9.17
# 2010          6.96
# 2011          7.02
# 2012          4.61
# 2013          8.79
# 2014          8.36
# 2015          7.26
# 2016          4.45
# 2017          4.37
# 2018          3.41
# 2019          3.49
# rata-rata     6.27
# dtype: float64

# %%
inflasi.min()
# Out:
# 2006         5.270000
# 2007         5.770000
# 2008         7.360000
# 2009         2.410000
# 2010         3.430000
# 2011         3.790000
# 2012         3.560000
# 2013         4.570000
# 2014         3.990000
# 2015         3.350000
# 2016         2.790000
# 2017         3.300000
# 2018         2.880000
# 2019         2.480000
# rata-rata    5.420769
# dtype: float64

# %%
inflasi.mean()
# Out:
# 2006         13.331667
# 2007          6.404167
# 2008         10.308333
# 2009          4.895000
# 2010          5.125000
# 2011          5.380000
# 2012          4.278333
# 2013          6.965833
# 2014          6.419167
# 2015          6.382500
# 2016          3.530833
# 2017          3.809167
# 2018          3.197500
# 2019          3.013750
# rata-rata     5.994689
# dtype: float64

# %%
plt.figure(figsize=(15,10)
plt.plot(inflasi.mean)
plt.show()
# Out:
#   File "<ipython-input-88-99809f7dfa68>", line 2
#     plt.plot(inflasi.mean)
#       ^
# SyntaxError: invalid syntax

# %%
data = pd.read_excel("H:\Tugas\Belajar\Python\inflasi3.xlsx")
data
# Out:
#     tahun    inflasi
# 0    2006  13.331667
# 1    2007   6.404167
# 2    2008  10.308333
# 3    2009   4.895000
# 4    2010   5.125000
# 5    2011   5.380000
# 6    2012   4.278333
# 7    2013   6.965833
# 8    2014   6.419167
# 9    2015   6.382500
# 10   2016   3.530833
# 11   2017   3.809167
# 12   2018   3.197500
# 13   2019   3.013750

# %%
plt.figure(figsize=(15,10))
plt.plot(data.tahun, data.inflasi)
plt.legend(['Inflasi'])
plt.xlabel('Tahun')
plt.ylabel('Tingkat Inflasi')
plt.show()

# %%
# Berdasarkan plot inflasi Indonesia di atas menunjukkan bahwa dari tahun ke tahun mengalami penurunan, meskipun terdapat sejumlah fluktuasi antara tahun 2007 dan 2008, di mana terjadinya krisis ekonomi global.
# Adapun tingkat inflasi tertinggi pada tahun 2006 yang mencapai angka 17.92. Sementara inflasi terendah pada tahun 2019 yang mencapai 2.4.
# Maka dapat diprediksi inflasi akan semakin menurun di tahun 2020 mendatang, Sementara berdasarkan rata-rata pertumbuhan IHK yang mempengaruhi inflasi, di mana permintaan barang dan jasa cenderung berkurang dan menyebabkan berkurangnya harga barang.
